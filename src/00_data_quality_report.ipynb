# %%
# %sql
CREATE TABLE IF NOT EXISTS workspace.default.capstone_bronze_sales9 (
    order_id INT,
    order_date DATE,
    customer_id STRING,
    customer_name STRING,
    city STRING,
    state STRING,
    product_id STRING,
    product_name STRING,
    category STRING,
    quantity INT,
    unit_price DOUBLE,
    discount_pct DOUBLE,
    gross_amount DOUBLE,
    discount_amount DOUBLE,
    net_amount DOUBLE,
    payment_method STRING,
    order_status STRING
)
USING DELTA;

# %%
spark.sql("DESCRIBE TABLE workspace.default.capstone_bronze_sales9")
